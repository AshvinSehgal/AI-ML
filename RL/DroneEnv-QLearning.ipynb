# %%
from Envs.DroneEnvDiscrete import DroneEnvDiscrete
from Algos.QLearning import QLearning

# %%
env = DroneEnvDiscrete()
agent = QLearning(env=env)

# %%
agent.learn()
agent.plotRewards()

# %%
agent.score()
agent.plotScore()

# %%
env.reset()
env.showEnv()
# Out:
# [['D' '.' '.' '.' '.' '.' '.' 'S' '.' '.']
#  ['.' '.' 'S' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' 'S' '.' '.']
#  ['.' '.' '.' '.' '.' 'S' '.' '.' '.' '.']
#  ['S' '.' '.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.' 'S' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' 'G' 'S' 'S' '.' 'S' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.' '.' '.']
#  ['.' '.' '.' '.' '.' '.' '.' '.' '.' 'S']]
